# %%
; exemplo de grafo direcionado com lista de adjacência
(define grafo-teste
  '(
    (A . (B C E))
    (B . (C))
    (C . (B E))
    (E . ())
  )
)

(define (filhos p grafo)
  (cdr (assq p grafo))
)

(filhos 'C grafo-teste)
# Out:
# (B E)
